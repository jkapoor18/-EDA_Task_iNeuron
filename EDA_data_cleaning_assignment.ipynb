# %%
# Importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

data = pd.read_csv("./adult.csv")

# %%
data
# Out:
#        39          State-gov   77516    Bachelors   13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1      38            Private  215646      HS-grad    9             Divorced
# 2      53            Private  234721         11th    7   Married-civ-spouse
# 3      28            Private  338409    Bachelors   13   Married-civ-spouse
# 4      37            Private  284582      Masters   14   Married-civ-spouse
# ...    ..                ...     ...          ...  ...                  ...
# 32555  27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad    9              Widowed
# 32558  22            Private  201490      HS-grad    9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %%
data_copy=data.copy()   #make copy of original data

# %%
data_copy.columns
# Out:
# Index(['39', ' State-gov', ' 77516', ' Bachelors', ' 13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' 2174', ' 0',
#        ' 40', ' United-States', ' <=50K'],
#       dtype='object')

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   39              32560 non-null  int64
#  1    State-gov      32560 non-null  object
#  2    77516          32560 non-null  int64
#  3    Bachelors      32560 non-null  object
#  4    13             32560 non-null  int64
#  5    Never-married  32560 non-null  object
#  6    Adm-clerical   32560 non-null  object
#  7    Not-in-family  32560 non-null  object
#  8    White          32560 non-null  object
#  9    Male           32560 non-null  object
#  10   2174           32560 non-null  int64
#  11   0              32560 non-null  int64
#  12   40             32560 non-null  int64
#  13   United-States  32560 non-null  object
#  14   <=50K          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data.describe(include='all').T
# Out:
#                   count unique                  top   freq           mean  \
# 39              32560.0    NaN                  NaN    NaN      38.581634
#  State-gov        32560      9              Private  22696            NaN
#  77516          32560.0    NaN                  NaN    NaN  189781.814373
#  Bachelors        32560     16              HS-grad  10501            NaN
#  13             32560.0    NaN                  NaN    NaN       10.08059
#  Never-married    32560      7   Married-civ-spouse  14976            NaN
#  Adm-clerical     32560     15       Prof-specialty   4140            NaN
#  Not-in-family    32560      6              Husband  13193            NaN
#  White            32560      5                White  27815            NaN
#  Male             32560      2                 Male  21789            NaN
#  2174           32560.0    NaN                  NaN    NaN    1077.615172
#  0              32560.0    NaN                  NaN    NaN      87.306511
# ...

# %%
data_copy[data_copy.duplicated()]
# Out:
#        39          State-gov   77516      Bachelors   13        Never-married  \
# 4880   25            Private  308144      Bachelors   13        Never-married
# 5103   90            Private   52386   Some-college   10        Never-married
# 9170   21            Private  250051   Some-college   10        Never-married
# 11630  20            Private  107658   Some-college   10        Never-married
# 13083  25            Private  195994        1st-4th    2        Never-married
# 15058  21            Private  243368      Preschool    1        Never-married
# 17039  46            Private  173243        HS-grad    9   Married-civ-spouse
# 18554  30            Private  144593        HS-grad    9        Never-married
# 18697  19            Private   97261        HS-grad    9        Never-married
# 21317  19            Private  138153   Some-college   10        Never-married
# 21489  19            Private  146679   Some-college   10        Never-married
# ...

# %%
data_copy.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
#checking null value
data_copy.isnull().sum()
# Out:
# 39                0
#  State-gov        0
#  77516            0
#  Bachelors        0
#  13               0
#  Never-married    0
#  Adm-clerical     0
#  Not-in-family    0
#  White            0
#  Male             0
#  2174             0
#  0                0
#  40               0
#  United-States    0
#  <=50K            0
# dtype: int64

# %%
data_copy.columns
# Out:
# Index(['39', ' State-gov', ' 77516', ' Bachelors', ' 13', ' Never-married',
#        ' Adm-clerical', ' Not-in-family', ' White', ' Male', ' 2174', ' 0',
#        ' 40', ' United-States', ' <=50K'],
#       dtype='object')

# %%
# Checking the unique values in the categorical columns
data_copy['39'].unique()
# Out:
# array([50, 38, 53, 28, 37, 49, 52, 31, 42, 30, 23, 32, 40, 34, 25, 43, 54,
#        35, 59, 56, 19, 39, 20, 45, 22, 48, 21, 24, 57, 44, 41, 29, 18, 47,
#        46, 36, 79, 27, 67, 33, 76, 17, 55, 61, 70, 64, 71, 68, 66, 51, 58,
#        26, 60, 90, 75, 65, 77, 62, 63, 80, 72, 74, 69, 73, 81, 78, 88, 82,
#        83, 84, 85, 86, 87], dtype=int64)

# %%
data_copy[' State-gov'].unique()
# Out:
# array([' Self-emp-not-inc', ' Private', ' State-gov', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
for col in data_copy.columns:
    print(col,data_copy[col].unique())
# Out:
# 39 [50 38 53 28 37 49 52 31 42 30 23 32 40 34 25 43 54 35 59 56 19 39 20 45
#  22 48 21 24 57 44 41 29 18 47 46 36 79 27 67 33 76 17 55 61 70 64 71 68
#  66 51 58 26 60 90 75 65 77 62 63 80 72 74 69 73 81 78 88 82 83 84 85 86
#  87]
#  State-gov [' Self-emp-not-inc' ' Private' ' State-gov' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
#  77516 [ 83311 215646 234721 ...  34066  84661 257302]
#  Bachelors [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
#  13 [13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
#  Never-married [' Married-civ-spouse' ' Divorced' ' Married-spouse-absent'
#  ' Never-married' ' Separated' ' Married-AF-spouse' ' Widowed']
#  Adm-clerical [' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Adm-clerical' ' Sales' ' Craft-repair'
# ...

# %% [markdown]
# # now lets clean the dataset or replacing unstructured values

# %%
data_copy=data_copy.rename(columns={"39":"Age"})
data_copy
# Out:
#        Age          State-gov   77516    Bachelors   13        Never-married  \
# 0       50   Self-emp-not-inc   83311    Bachelors   13   Married-civ-spouse
# 1       38            Private  215646      HS-grad    9             Divorced
# 2       53            Private  234721         11th    7   Married-civ-spouse
# 3       28            Private  338409    Bachelors   13   Married-civ-spouse
# 4       37            Private  284582      Masters   14   Married-civ-spouse
# ...    ...                ...     ...          ...  ...                  ...
# 32555   27            Private  257302   Assoc-acdm   12   Married-civ-spouse
# 32556   40            Private  154374      HS-grad    9   Married-civ-spouse
# 32557   58            Private  151910      HS-grad    9              Widowed
# 32558   22            Private  201490      HS-grad    9        Never-married
# 32559   52       Self-emp-inc  287927      HS-grad    9   Married-civ-spouse
#
# ...

# %% [markdown]
# # Here updating the column name

# %%
data_copy=data_copy.rename(columns={' State-gov':'Workclass'})
data_copy=data_copy.rename(columns={' 40':'Hour'})
data_copy=data_copy.rename(columns={' Never-married':'Marital-status'})
data_copy=data_copy.rename(columns={' Adm-clerical':'Occupation'})
data_copy=data_copy.rename(columns={' Not_in_family':'Relationship'})
data_copy=data_copy.rename(columns={' White':'Race'})
data_copy=data_copy.rename(columns={' Male':'Gender'})
data_copy=data_copy.rename(columns={' United-States':'Country'})
data_copy=data_copy.rename(columns={' <=50K':'Salary'})
data_copy=data_copy.rename(columns={' 2174':'Capital-gain'})
data_copy=data_copy.rename(columns={' 0':'Capital-loss'})
data_copy=data_copy.rename(columns={' 77516':'Fcode'})
data_copy=data_copy.rename(columns={' 13':'Education-num'})
data_copy=data_copy.rename(columns={' Bachelors':'Education'})

data_copy.head()
# Out:
#    Age          Workclass   Fcode   Education  Education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital-status          Occupation   Not-in-family    Race   Gender  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital-gain  Capital-loss  Hour         Country  Salary
# 0             0             0    13   United-States   <=50K
# ...

# %%
data_copy
# Out:
#        Age          Workclass   Fcode    Education  Education-num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital-status          Occupation   Not-in-family    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
data_copy['Salary'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
char_to_remove=[">","<","="]
cols_to_clean=['Salary']
for item in char_to_remove:
    for col in cols_to_clean:
        data_copy[col]=data_copy[col].str.replace(item,"")

# %%
data_copy.head()
# Out:
#    Age          Workclass   Fcode   Education  Education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital-status          Occupation   Not-in-family    Race   Gender  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital-gain  Capital-loss  Hour         Country Salary
# 0             0             0    13   United-States    50K
# ...

# %%
char_to_remove=["K"]
cols_to_clean=['Salary']
for item in char_to_remove:
    for col in cols_to_clean:
        data_copy[col]=data_copy[col].str.replace(item,"000")

# %%
data_copy.head()
# Out:
#    Age          Workclass   Fcode   Education  Education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital-status          Occupation   Not-in-family    Race   Gender  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital-gain  Capital-loss  Hour         Country  Salary
# 0             0             0    13   United-States   50000
# ...

# %%
#data_copy['Salary'].value_counts()

# %%
#data_copy=data_copy['Salary'].astype(int)

# %%
#data_copy['Salary'].dtype

# %%
#data_copy.info()

# %%
data_copy['Workclass']=data_copy['Workclass'].str.replace('?',"Nan")

# %%
data_copy['Occupation']=data_copy['Occupation'].str.replace('?',"Nan")
data_copy['Country']=data_copy['Country'].str.replace('?',"Nan")

# %%
data_copy.head(50)
# Out:
#     Age          Workclass   Fcode      Education  Education-num  \
# 0    50   Self-emp-not-inc   83311      Bachelors             13
# 1    38            Private  215646        HS-grad              9
# 2    53            Private  234721           11th              7
# 3    28            Private  338409      Bachelors             13
# 4    37            Private  284582        Masters             14
# 5    49            Private  160187            9th              5
# 6    52   Self-emp-not-inc  209642        HS-grad              9
# 7    31            Private   45781        Masters             14
# 8    42            Private  159449      Bachelors             13
# 9    37            Private  280464   Some-college             10
# 10   30          State-gov  141297      Bachelors             13
# 11   23            Private  122272      Bachelors             13
# 12   32            Private  205019     Assoc-acdm             12
# ...

# %%
#numeric_features = [feature for feature in data_copy.columns if data_copy[feature].dtype !='O']

# %% [markdown]
# # now ploting graph

# %%
plt.figure(figsize=(12,6))
sns.histplot(data_copy['Age'], bins=20, kde=True)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age')
plt.show()

# %% [markdown]
# # it shows that the majority of the individuals in the dataset are between the ages of 20 and 50.

# %%
# Distribution of workclass
plt.figure(figsize=(12,6))
sns.countplot(x='Workclass', data=data_copy)
plt.xlabel('Workclass')
plt.ylabel('Count')
plt.title('Distribution of Workclass')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # majority of workclass in private sector

# %%
# Distribution of race
plt.figure(figsize=(12,6))
sns.countplot(x='Race', data=data_copy)
plt.xlabel('Race')
plt.ylabel('Count')
plt.title('Distribution of Race')
plt.xticks(rotation=45)
plt.show()

# %%
# Distribution of sex
plt.figure(figsize=(12,6))
sns.countplot(x='Gender', data=data_copy)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution of Gender')
plt.xticks(rotation=45)
plt.show()

# %%
# Distribution of native country
plt.figure(figsize=(12,6))
sns.countplot(y='Country', data=data_copy)
plt.xlabel('Count')
plt.ylabel('Country')
plt.title('Distribution of Country')
plt.xticks(rotation=45)
plt.show()

# %%
# Relationship between education and salary
plt.figure(figsize=(12,6))
sns.countplot(x='Education', hue='Salary', data=data_copy)
plt.xlabel('Education')
plt.ylabel('Count')
plt.title('Relationship between Education and Salary')
plt.xticks(rotation=45)
plt.legend(title='Salary', loc='upper right')
plt.show()

# %%
# Relationship between workclass and salary
plt.figure(figsize=(12,6))
sns.countplot(x='Workclass', hue='Salary', data=data_copy)
plt.xlabel('Workclass')
plt.ylabel('Count')
plt.title('Relationship between Workclass and Salary')
plt.xticks(rotation=45)
plt.legend(title='Salary', loc='upper right')
plt.show()

# %%
# Relationship between marital status and salary
plt.figure(figsize=(12,6))
sns.countplot(x='Marital-status', hue='Salary', data=data_copy)
plt.xlabel('Marital-status')
plt.ylabel('Count')
plt.title('Relationship between Marital-status and Salary')
plt.xticks(rotation=45)
plt.legend(title='Salary', loc='upper right')
plt.show()

# %%
data_copy
# Out:
#        Age          Workclass   Fcode    Education  Education-num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital-status          Occupation   Not-in-family    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...
